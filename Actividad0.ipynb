# %% [markdown]
#  ## ACTIVIDAD 0 - IVAN ALEJANDRO PEDRAZA MACIAS

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.2.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 34 kB/s
# Collecting py4j==0.10.9.3
#   Downloading py4j-0.10.9.3-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 67.7 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.1-py2.py3-none-any.whl size=281853642 sha256=dad05617219ab2159b4b0aabb2eab5f6ef35995d935e9e991a7c1ea2cda622fb
#   Stored in directory: /root/.cache/pip/wheels/9f/f5/07/7cd8017084dce4e93e84e92efd1e1d5334db05f2e83bcef74f
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.3 pyspark-3.2.1

# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext()

# %%
import pyspark as ps
import random

spark = ps.sql.SparkSession.builder \
        .appName("rdd test") \
        .getOrCreate()

random.seed(1)

def sample(p):
    x, y = random.random(), random.random()
    return 1 if x*x + y*y < 1 else 0

count = spark.sparkContext.parallelize(range(0, 10000000)).map(sample) \
        .reduce(lambda a, b: a + b)

print("Pi is (very) roughly {}".format(4.0 * count / 10000000))
# Out:
# Pi is (very) roughly 3.141446
